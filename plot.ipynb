# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Size of graph varying from 1 * 10 ^ 5 to 6 * 10 ^ 5 in the increments of 10 ^ 5 # of threads: 16

# %%
x = np.array([
    100000, 200000, 300000, 400000, 500000, 600000
])

seq = np.array([
    (138986 + 141636 + 139026 + 140915 + 142697)/5,
    (318584 + 324555 + 318702 + 320207 + 325564)/5,
    (553267 + 548667 + 544503 + 541110 + 543551)/5,
    (788396 + 789077 + 787938 + 788132 + 796122)/5,
    (1037590 + 1036038 + 1037083 + 1037259 + 1038563)/5,
    (1278252 + 1278961 + 1277425 + 1281363 + 1275457)/5,
])

wf = np.array([
    (31810 + 32244 + 31453 + 32102 + 33016)/5,
    (45275 + 48662 + 47636 + 47463 + 48931)/5,
    (67412 + 67174 + 66053 + 65497 + 67342)/5,
    (86296 + 87722 + 87724 + 79196 + 89285)/5,
    (107137 + 103662 + 99831 + 106582 + 105489)/5,
    (126858 + 124029 + 126587 + 125762 + 126548)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, seq, label = "Sequential")
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of nodes")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("wf : ", wf)
print("seq : ", seq)
print("speed-up : ", speed_up)
# Out:
# wf :  [ 32125.   47593.4  66695.6  86044.6 104540.2 125956.8]
# seq :  [ 140652.   321522.4  546219.6  789933.  1037306.6 1278291.6]
# speed-up :  [ 4.37827237  6.75560897  8.18973965  9.18050639  9.92256185 10.14865097]

# %%
# Number of threads varying from 2 to 32 in the powers of 2, Graph Size: 5 * 10 ^ 5

# %%
x = np.array([
    2, 4, 8, 16, 32
])

seq = (1043298 + 1039328 + 1068027 + 1043901 + 1041332)/5

wf = np.array([
    (544757 + 547451 + 555616 + 555156 + 549093)/5,
    (299197 + 303464 + 300161 + 300798 + 298521)/5,
    (172562 + 171734 + 173282 + 168302 + 170906)/5,
    (105357 + 106505 + 100433 + 106150 + 105825)/5,
    (71760 + 67297 + 69505 + 76367 + 71602)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("speed-up : ", speed_up)
# Out:
# seq :  1047177.2
# wf :  [550414.6 300428.2 171357.2 104854.   71306.2]
# speed-up :  [ 1.90252439  3.48561553  6.11107791  9.98700288 14.68564024]

# %%
# socLiveJournal

# %%
x = np.array([
    2, 4, 8, 16, 32
])

seq = (3432263 + 3474761 + 3435659 + 3493911 + 3431225)/5

wf = np.array([
    (1969542 + 1950371 + 1969722 + 2009730 + 1972960)/5,
    (1123603 + 1080111 + 1098814 + 1113091 + 1090500)/5,
    (586526 + 606961 + 613610 + 593048 + 624589)/5,
    (416820 + 391723 + 388980 + 403508 + 405789)/5,
    (275316 + 281296 + 278160 + 284719 + 269155)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("speed-up : ", speed_up)
# Out:
# seq :  3453563.8
# wf :  [1974465.  1101223.8  604946.8  401364.   277729.2]
# speed-up :  [ 1.74911371  3.13611438  5.70887192  8.60456792 12.43500431]

# %%
# soc-sinaweibo

# %%
x = np.array([
    2, 4, 8, 16, 32
])

seq = (38422539 + 39583894 + 39032098 + 39620620 + 38430086)/5

wf = np.array([
    (23343650 + 25109608 + 24404034 + 25667522 + 23773247)/5,
    (12794323 + 14423326 + 13461333 + 13264592 + 13301430)/5,
    (8295764 + 7431880 + 7981091 + 8174041 + 8498439)/5,
    (4507173 + 4419536 + 4406976 + 4568624 + 4217125)/5,
    (2560073 + 2615369 + 2587736 + 2570038 + 2613626)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("speed-up : ", speed_up)
# Out:
# seq :  39017847.4
# wf :  [24459612.2 13449000.8  8076243.   4423886.8  2589368.4]
# speed-up :  [ 1.59519485  2.90117072  4.83118789  8.81981144 15.06848056]

# %%
# Varying the sleep time of threads exponentially distributed in the range 1 to 5 ms

# %%
x = np.array([
    1, 2, 3, 4, 5
])

seq = (989430 + 995957 + 1001199 + 989769 + 998968)/5

wf = np.array([
    (123458 + 123771 + 124033 + 117832 + 115753)/5,
    (126889 + 126547 + 121425 + 122771 + 127887)/5,
    (136147 + 131940 + 131498 + 128371 + 117245)/5,
    (141919 + 139362 + 130264 + 136955 + 142601)/5,
    (140963 + 142884 + 141176 + 134316 + 143614)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("Mean Sleep Time")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("speed-up : ", speed_up)
# Out:
# seq :  995064.6
# wf :  [120969.4 125103.8 129040.2 138220.2 140590.6]
# speed-up :  [8.22575461 7.95391187 7.71127602 7.19912574 7.07774631]

# %%
# Varying the the number of failure threads from 1 to 8 in the powers of 2

# %%
x = np.array([
    1, 2, 4, 8, 15
])

seq = np.array([
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
])

wf = np.array([
    (116056 + 103846 + 110329 + 109072 + 105318)/5,
    (112820 + 114536 + 113106 + 120805 + 117289)/5,
    (130464 + 126578 + 119632 + 123492 + 130186)/5,
    (174834 + 163237 + 166974 + 169285 + 176420)/5,
    (1005178 + 1025973 + 1021318 + 1025763 + 1025311)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, wf, label = "Wait-Free")
plt.plot(x, seq, label = "Sequential")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("speed-up : ", speed_up)
# Out:
# seq :  [995064.6 995064.6 995064.6 995064.6 995064.6]
# wf :  [ 108924.2  115711.2  126070.4  170150.  1020708.6]
# speed-up :  [9.13538589 8.59955303 7.89292808 5.84816103 0.97487628]

# %%
21264286/1296474
# Out:
# 16.401629342354724
