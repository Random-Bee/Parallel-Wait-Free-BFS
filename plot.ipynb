# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Size of graph varying from 1 * 10 ^ 5 to 6 * 10 ^ 5 in the increments of 10 ^ 5 # of threads: 16

# %%
x = np.array([
    100000, 200000, 300000, 400000, 500000, 600000
])

seq = np.array([
    (142184 + 139715 + 145609 + 140246 + 142425)/5,
    (305234 + 306693 + 310472 + 303140 + 302969)/5,
    (542565 + 543549 + 543841 + 542839 + 544244)/5,
    (772216 + 789326 + 791936 + 791443 + 790700)/5,
    (1016499 + 1020125 + 1014205 + 1015808 + 1019688)/5,
    (1256305 + 1254047 + 1254089 + 1251639 + 1254748)/5,
])

wf = np.array([
    (33489 + 32170 + 32452 + 32920 + 31576)/5,
    (50402 + 49723 + 51095 + 49446 + 49317)/5,
    (72207 + 71830 + 71597 + 70788 + 70531)/5,
    (90681 + 93362 + 87813 + 90414 + 90985)/5,
    (113250 + 113397 + 112507 + 110291 + 113821)/5,
    (133395 + 132882 + 133322 + 129409 + 131716)/5,
])

wfa = np.array([
    (30810 + 30620 + 28986 + 33694 + 32296)/5,
    (48815 + 48175 + 48025 + 45884 + 47256)/5,
    (65754 + 64937 + 63743 + 65953 + 66098)/5,
    (82734 + 87023 + 84066 + 85019 + 86003)/5,
    (104836 + 105696 + 98528 + 104593 + 105757)/5,
    (122630 + 117808 + 124469 + 118586 + 125279)/5,
])

bar = np.array([
    (92399 + 92853 + 92357 + 92262 + 92334)/5,
    (174354 + 173110 + 173390 + 173321 + 175128)/5,
    (262098 + 260996 + 263465 + 261801 + 262798)/5,
    (348004 + 346208 + 347199 + 347505 + 347522)/5,
    (429909 + 431728 + 431058 + 429908 + 430238)/5,
    (516555 + 516244 + 520247 + 540175 + 518456)/5,
])

speed_up_wf = seq/wf
speed_up_wfa = seq/wfa
speed_up_bar = seq/bar

plt.figure()
plt.plot(x, seq, label = "Sequential")
plt.plot(x, bar, label = "Barrier")
plt.plot(x, wfa, label = "Wait-Free Atomic")
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of nodes")
plt.ylabel("Time (in microseconds)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("wfa : ", wfa)
print("bar : ", bar)
print("speed-up-wf : ", speed_up_wf)
print("speed-up-wfa : ", speed_up_wfa)
print("speed-up-bar : ", speed_up_bar)
# Out:
# seq :  39017847.4
# wf :  [21493065.4 11186974.8  6841615.2  3613980.6  2282503.6  1554303. ]
# wfa :  [23767431.8 13178536.4  7383844.8  4645082.   2791807.2  2067673. ]
# bar :  [36481333.2 19470851.4 11802075.   7381050.4  5650767.4  4568624.4]
# speed-up-wf :  [ 1.81536913  3.48779255  5.70301694 10.79636327 17.0943202  25.10311529]
# speed-up-wfa :  [ 1.64165181  2.96071174  5.28421824  8.39981886 13.9758388  18.87041491]
# speed-up-bar :  [1.0695291  2.0039107  3.30601588 5.2862188  6.90487586 8.5403929 ]

# %%
# Number of threads varying from 2 to 32 in the powers of 2, Graph Size: 5 * 10 ^ 5

# %%
x = np.array([
    2, 4, 8, 16, 32, 64
])

seq = (1019204 + 1014448 + 1016866 + 1015791 + 1016717)/5

wf = np.array([
    (649687 + 650924 + 649635 + 649444 + 648060)/5,
    (343358 + 343800 + 341364 + 342528 + 342795)/5,
    (184447 + 186117 + 185114 + 189629 + 185144)/5,
    (109980 + 109665 + 112227 + 109297 + 111604)/5,
    (73053 + 73533 + 73030 + 74744 + 73781)/5,
    (59993 + 60592 + 60597 + 60248 + 60788)/5,
])

wfa = np.array([
    (529658 + 540524 + 561067 + 532280 + 549874)/5,
    (299541 + 299685 + 303721 + 302167 + 300695)/5,
    (161134 + 162795 + 165146 + 161301 + 161573)/5,
    (97859 + 103388 + 99096 + 102130 + 100930)/5,
    (66989 + 65553 + 71970 + 68966 + 66025)/5,
    (55262 + 57721 + 55021 + 53745 + 57153)/5,
])

bar = np.array([
    (1359605 + 1342149 + 1362134 + 1362281 + 1356179)/5,
    (829035 + 830601 + 839449 + 834290 + 835934)/5,
    (456782 + 452513 + 453946 + 452592 + 456963)/5,
    (387301 + 407267 + 384879 + 387096 + 394023)/5,
    (237150 + 226342 + 226621 + 225344 + 227560)/5,
    (153296 + 159668 + 154844 + 154419 + 154836)/5,
])

speed_up_wf = seq/wf
speed_up_wfa = seq/wfa
speed_up_bar = seq/bar

plt.figure()
plt.plot(x, bar, label = "Barrier")
plt.plot(x, wfa, label = "Wait-Free Atomic")
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("wfa : ", wfa)
print("bar : ", bar)
print("speed-up wf : ", speed_up_wf)
print("speed-up wfa : ", speed_up_wfa)
print("speed-up bar : ", speed_up_bar)
# Out:
# seq :  1016605.2
# wf :  [649550.  342769.  186090.2 110554.6  73628.2  60443.6]
# wfa :  [542680.6 301161.8 162389.8 100680.6  67900.6  55780.4]
# bar :  [1356469.6  833861.8  454559.2  392113.2  228603.4  155412.6]
# speed-up wf :  [ 1.56509152  2.96586097  5.46297011  9.1955034  13.80728036 16.819071  ]
# speed-up wfa :  [ 1.87330301  3.37561138  6.26027743 10.09732957 14.97196196 18.22513284]
# speed-up bar :  [0.74944931 1.2191531  2.23646381 2.59263192 4.44702572 6.54133063]

# %%
# socLiveJournal

# %%
x = np.array([
    2, 4, 8, 16, 32, 64
])

seq = (3432263 + 3474761 + 3435659 + 3493911 + 3431225)/5

wf = np.array([
    (2034311 + 2016869 + 2025190 + 2012034 + 2038106)/5,
    (1116764 + 1097108 + 1095304 + 1105990 + 1080965)/5,
    (600757 + 585958 + 586897 + 607609 + 601868)/5,
    (408025 + 383728 + 400188 + 364300 + 391822)/5,
    (271023 + 269464 + 271554 + 262852 + 281690)/5,
    (160376 + 172879 + 169041 + 175928 + 167603)/5,
])

wfa = np.array([
    (1908178 + 1917985 + 1942091 + 1901754 + 1914392)/5,
    (1082885 + 1064333 + 1042166 + 1083234 + 1044311)/5,
    (570921 + 574156 + 568780 + 582660 + 561562)/5,
    (355719 + 384099 + 390673 + 396204 + 369500)/5,
    (249799 + 259306 + 260709 + 277032 + 221041)/5,
    (201156 + 199307 + 197043 + 216647 + 204168)/5,
])

bar = np.array([
    (3010652 + 3007615 + 3044335 + 3017594 + 2998882)/5,
    (1768534 + 1769404 + 1768242 + 1773576 + 1762450)/5,
    (1255226 + 1052751 + 1219383 + 1046410 + 1237961)/5,
    (764448 + 768798 + 785741 + 773579 + 790211)/5,
    (488926 + 489878 + 520859 + 476696 + 505268)/5,
    (364627 + 359737 + 371350 + 343630 + 352996)/5,
])

speed_up_wf = seq/wf
speed_up_wfa = seq/wfa
speed_up_bar = seq/bar

plt.figure()
plt.plot(x, bar, label = "Barrier")
plt.plot(x, wfa, label = "Wait-Free Atomic")
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("wfa : ", wfa)
print("bar : ", bar)
print("speed-up wf : ", speed_up_wf)
print("speed-up wfa : ", speed_up_wfa)
print("speed-up bar : ", speed_up_bar)
# Out:
# seq :  39017847.4
# wf :  [21493065.4 11186974.8  6841615.2  3613980.6  2282503.6  1554303. ]
# wfa :  [23767431.8 13178536.4  7383844.8  4645082.   2791807.2  2067673. ]
# bar :  [36481333.2 19470851.4 11802075.   7381050.4  5650767.4  4568624.4]
# speed-up wf :  [ 1.81536913  3.48779255  5.70301694 10.79636327 17.0943202  25.10311529]
# speed-up wfa :  [ 1.64165181  2.96071174  5.28421824  8.39981886 13.9758388  18.87041491]
# speed-up bar :  [1.0695291  2.0039107  3.30601588 5.2862188  6.90487586 8.5403929 ]

# %%
# soc-sinaweibo

# %%
x = np.array([
    2, 4, 8, 16, 32, 64
])

seq = (38422539 + 39583894 + 39032098 + 39620620 + 38430086)/5

wf = np.array([
    (20593598 + 20198107 + 21379544 + 21607593 + 23686485)/5,
    (11936696 + 11015761 + 11008016 + 10738250 + 11236151)/5,
    (6646192 + 6981258 + 6835912 + 7046237 + 6698477)/5,
    (3639930 + 3892954 + 3228202 + 3696169 + 3612648)/5,
    (2312992 + 2269827 + 2367804 + 2149524 + 2312371)/5,
    (1525881 + 1555875 + 1542783 + 1561455 + 1585521)/5,
])

wfa = np.array([
    (24229024 + 23376901 + 25859335 + 22977196 + 22394703)/5,
    (13462463 + 13386960 + 12670063 + 13286338 + 13086858)/5,
    (7119590 + 7872043 + 8131360 + 6859061 + 6937170)/5,
    (4368852 + 4714720 + 5162728 + 4323602 + 4655508)/5,
    (2773165 + 2983711 + 2654131 + 2706138 + 2841891)/5,
    (1961446 + 1924492 + 2318472 + 2013874 + 2120081)/5,
])

bar = np.array([
    (36166935 + 36749544 + 35778417 + 36437161 + 37274609)/5,
    (19201535 + 19544046 + 19413021 + 19787623 + 19408032)/5,
    (12555350 + 12956849 + 11303227 + 9735931 + 12459018)/5,
    (6460733 + 7660427 + 7585788 + 7604086 + 7594218)/5,
    (5636407 + 5717024 + 5665346 + 5419992 + 5815068)/5,
    (4813878 + 4474693 + 4472680 + 4310605 + 4771266)/5,
])

speed_up_wf = seq/wf
speed_up_wfa = seq/wfa
speed_up_bar = seq/bar

plt.figure()
plt.plot(x, bar, label = "Barrier")
plt.plot(x, wfa, label = "Wait-Free Atomic")
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("wfa : ", wfa)
print("bar : ", bar)
print("speed-up wf : ", speed_up_wf)
print("speed-up wfa : ", speed_up_wfa)
print("speed-up bar : ", speed_up_bar)
# Out:
# seq :  39017847.4
# wf :  [21493065.4 11186974.8  6841615.2  3613980.6  2282503.6  1554303. ]
# wfa :  [23767431.8 13178536.4  7383844.8  4645082.   2791807.2  2067673. ]
# bar :  [36481333.2 19470851.4 11802075.   7381050.4  5650767.4  4568624.4]
# speed-up wf :  [ 1.81536913  3.48779255  5.70301694 10.79636327 17.0943202  25.10311529]
# speed-up wfa :  [ 1.64165181  2.96071174  5.28421824  8.39981886 13.9758388  18.87041491]
# speed-up bar :  [1.0695291  2.0039107  3.30601588 5.2862188  6.90487586 8.5403929 ]

# %%
# Varying the sleep time of threads exponentially distributed in the range 1 to 5 ms

# %%
x = np.array([
    1, 2, 3, 4, 5
])

seq = (1048172 + 1046099 + 1046242 + 1046524 + 1044156)/5

wf = np.array([
    (118221 + 117668 + 122858 + 117771 + 118853)/5,
    (130433 + 124254 + 120062 + 128546 + 121981)/5,
    (121884 + 125393 + 130053 + 128830 + 125178)/5,
    (125927 + 132056 + 137834 + 126058 + 130066)/5,
    (127217 + 137115 + 130008 + 133043 + 133178)/5,
])

bar = np.array([
    (433893 + 439013 + 433621 + 436026 + 437887)/5,
    (448866 + 443502 + 411977 + 451555 + 447025)/5,
    (447682 + 455092 + 456160 + 450230 + 496423)/5,
    (454538 + 472391 + 460969 + 462874 + 465372)/5,
    (469628 + 460477 + 492624 + 467071 + 492443)/5,
])

speed_up_wf = seq/wf
speed_up_bar = seq/bar

plt.figure()
plt.plot(x, bar, label = "Barrier")
plt.plot(x, wf, label = "Wait-Free")
plt.xlabel("Mean Sleep Time")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("bar : ", bar)
print("speed-up : ", speed_up_wf)
print("speed-up : ", speed_up_bar)
# Out:
# seq :  1046238.6
# wf :  [119074.2 125055.2 126267.6 130388.2 132112.2]
# bar :  [436088.  440585.  461117.4 463228.8 476448.6]
# speed-up :  [8.7864424  8.36621428 8.28588331 8.02402825 7.91931858]
# speed-up :  [2.39914559 2.37465778 2.26892024 2.25857848 2.19591074]

# %%
# Varying the the number of failure threads from 1 to 8 in the powers of 2

# %%
x = np.array([
    1, 2, 4, 8, 15
])

seq = np.array([
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
    (989430 + 995957 + 1001199 + 989769 + 998968)/5,
])

wf = np.array([
    (116056 + 103846 + 110329 + 109072 + 105318)/5,
    (112820 + 114536 + 113106 + 120805 + 117289)/5,
    (130464 + 126578 + 119632 + 123492 + 130186)/5,
    (174834 + 163237 + 166974 + 169285 + 176420)/5,
    (1005178 + 1025973 + 1021318 + 1025763 + 1025311)/5,
])

speed_up = seq/wf

plt.figure()
plt.plot(x, wf, label = "Wait-Free")
plt.plot(x, seq, label = "Sequential")
plt.xlabel("No. of Threads")
plt.ylabel("Time (in µs)")
plt.legend()
plt.show()

# %%
print("seq : ", seq)
print("wf : ", wf)
print("speed-up : ", speed_up)
# Out:
# seq :  [995064.6 995064.6 995064.6 995064.6 995064.6]
# wf :  [ 108924.2  115711.2  126070.4  170150.  1020708.6]
# speed-up :  [9.13538589 8.59955303 7.89292808 5.84816103 0.97487628]

# %%
21264286/1296474
# Out:
# 16.401629342354724
